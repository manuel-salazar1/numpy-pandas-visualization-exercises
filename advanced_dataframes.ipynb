# %%
import pandas as pd
import numpy as np

# %%
from env import username, password, get_db_url

# %% [markdown]
# Create a function named get_db_url. It should accept a username, hostname, password, and database name and return a url connection string formatted like in the example at the start of this lesson.

# %%
def get_db_url(database_name):
    database_name = database_name
    return f'mysql+pymysql://{username}:{password}@data.codeup.com/{database_name}'

# %%
url = get_db_url('employees')

# %%
pd.read_sql('select * from employees limit 5', url)
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12

# %%
pd.read_sql('select * from employees limit 5 offset 50', url) #example of making a typo .. employeees instead of employees
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3280, in Engine._wrap_pool_connect(self, fn, connection)
#    3279 try:
# -> 3280     return fn()
#    3281 except dialect.dbapi.Error as e:
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# --> 868     fairy = _ConnectionRecord.checkout(pool)
#     870     fairy._pool = pool
#
# ...

# %%
# b. Intentionally make an error in your SQL query. What does the error message look like?


pd.read_sql('select * from employees where to_date>now()', url)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pymysql/cursors.py:158, in Cursor.execute(self, query, args)
# ...

# %%
# Read the employees and titles tables into two separate DataFrames.
employees = pd.read_sql('select * from employees', url)
employees
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
# ...        ...         ...        ...       ...    ...         ...
# 300019  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12
# 300020  499996  1953-03-07       Zito      Baaz      M  1990-09-27
# 300021  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 300022  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 300023  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
# [300024 rows x 6 columns]

# %%
titles = pd.read_sql('select * from titles', url)
titles
# Out:
#         emp_no            title   from_date     to_date
# 0        10001  Senior Engineer  1986-06-26  9999-01-01
# 1        10002            Staff  1996-08-03  9999-01-01
# 2        10003  Senior Engineer  1995-12-03  9999-01-01
# 3        10004         Engineer  1986-12-01  1995-12-01
# 4        10004  Senior Engineer  1995-12-01  9999-01-01
# ...        ...              ...         ...         ...
# 443303  499997         Engineer  1987-08-30  1992-08-29
# 443304  499997  Senior Engineer  1992-08-29  9999-01-01
# 443305  499998     Senior Staff  1998-12-27  9999-01-01
# 443306  499998            Staff  1993-12-27  1998-12-27
# 443307  499999         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 4 columns]

# %%
# How many rows and columns do you have in each DataFrame? Is that what you expected?
# employees has 300024 rows × 6 columns
# titles has 443308 rows × 4 columns
# yes, I expected this outcome

# %%
# Display the summary statistics for each DataFrame.

employees.describe()
# Out:
#               emp_no
# count  300024.000000
# mean   253321.763392
# std    161828.235540
# min     10001.000000
# 25%     85006.750000
# 50%    249987.500000
# 75%    424993.250000
# max    499999.000000

# %%
titles.describe()
# Out:
#               emp_no
# count  443308.000000
# mean   253075.034430
# std    161853.292613
# min     10001.000000
# 25%     84855.750000
# 50%    249847.500000
# 75%    424891.250000
# max    499999.000000

# %%
# How many unique titles are in the titles DataFrame?
pd.read_sql('''
select distinct title 
from titles

'''
, url).count()
# Out:
# title    7
# dtype: int64

# %%
titles.title.nunique()
# Out:
# 7

# %%
len(titles.title.unique())
# Out:
# 7

# %%
# What is the oldest date in the to_date column?

pd.read_sql('''
    select *
    from titles
    order by to_date
    limit 1
    ''', url)
# Out:
#    emp_no     title   from_date     to_date
# 0   20869  Engineer  1985-02-17  1985-03-01

# %%
titles.to_date.min()
# Out:
# datetime.date(1985, 3, 1)

# %%
# What is the most recent date in the to_date column?

pd.read_sql('''
    select *
    from titles
    order by to_date desc
    limit 1
    ''', url)
# Out:
#    emp_no            title   from_date     to_date
# 0   10001  Senior Engineer  1986-06-26  9999-01-01

# %%
titles.to_date.max()
# Out:
# datetime.date(9999, 1, 1)

# %%
titles[titles.to_date != titles.to_date.max()].to_date.max()
# Out:
# datetime.date(2002, 8, 1)

# %% [markdown]
# # Exercises II

# %% [markdown]
# #### 1. Copy the users and roles DataFrames from the examples above.

# %%
# Create the users DataFrame.

users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %%
# Create the roles DataFrame

roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %% [markdown]
# #### 2. What is the result of using a right join on the DataFrames?

# %%
users.merge(roles, how='right')
# Out:
#    id       name  role_id
# 0   1      admin      NaN
# 1   2     author      NaN
# 2   3   reviewer      NaN
# 3   4  commenter      NaN

# %%
pd.merge(users, roles, how='right', left_on='role_id', right_on='id')
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0     1      admin
# 1   2.0    joe      2.0     2     author
# 2   3.0  sally      3.0     3   reviewer
# 3   4.0   adam      3.0     3   reviewer
# 4   NaN    NaN      NaN     4  commenter

# %% [markdown]
# #### 3. What is the result of using an outer join on the DataFrames?

# %%
users.merge(roles, how='outer')
# Out:
#    id       name  role_id
# 0   1        bob      1.0
# 1   2        joe      2.0
# 2   3      sally      3.0
# 3   4       adam      3.0
# 4   5       jane      NaN
# 5   6       mike      NaN
# 6   1      admin      NaN
# 7   2     author      NaN
# 8   3   reviewer      NaN
# 9   4  commenter      NaN

# %%
pd.merge(users, roles, how='outer', left_on='role_id', right_on='id')
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0   1.0      admin
# 1   2.0    joe      2.0   2.0     author
# 2   3.0  sally      3.0   3.0   reviewer
# 3   4.0   adam      3.0   3.0   reviewer
# 4   5.0   jane      NaN   NaN        NaN
# 5   6.0   mike      NaN   NaN        NaN
# 6   NaN    NaN      NaN   4.0  commenter

# %% [markdown]
# #### 4. What happens if you drop the foreign keys from the DataFrames and try to merge them?

# %%
users.merge(roles, how='outer').drop(columns='role_id')
# Out:
#    id       name
# 0   1        bob
# 1   2        joe
# 2   3      sally
# 3   4       adam
# 4   5       jane
# 5   6       mike
# 6   1      admin
# 7   2     author
# 8   3   reviewer
# 9   4  commenter

# %%
users.drop(columns='role_id')

# %%
pd.merge(users,roles,how='inner',on='id')

# %% [markdown]
# #### 5. Load the mpg dataset from PyDataset.

# %%
from pydataset import data
mpg = data('mpg')

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %% [markdown]
# #### 6. Output and read the documentation for the mpg dataset.

# %%
data('mpg', show_doc=True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %% [markdown]
# #### 7. How many rows and columns are in the dataset?

# %%
mpg.shape
# Out:
# (234, 11)

# %% [markdown]
# #### 8. Check out your column names and perform any cleanup you may want on them.

# %%
mpg = mpg.rename(columns={'cty': 'city', 'hwy': 'highway'})
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class
# 1    compact
# 2    compact
# ...

# %% [markdown]
# #### 9. Display the summary statistics for the dataset.

# %%
mpg.describe()
# Out:
#             displ         year         cyl        city     highway
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %% [markdown]
# #### 10. How many different manufacturers are there?

# %%
mpg.groupby('manufacturer').describe() # 15 manufacturers
# Out:
#              displ                                                       year  \
#              count      mean           std  min    25%  50%    75%  max count
# manufacturer
# audi          18.0  2.544444  6.732032e-01  1.8  2.000  2.8  3.025  4.2  18.0
# chevrolet     19.0  5.063158  1.370406e+00  2.4  4.450  5.3  5.850  7.0  19.0
# dodge         37.0  4.378378  8.679910e-01  2.4  3.800  4.7  4.700  5.9  37.0
# ford          25.0  4.536000  5.407402e-01  3.8  4.000  4.6  4.600  5.4  25.0
# honda          9.0  1.711111  1.452966e-01  1.6  1.600  1.6  1.800  2.0   9.0
# hyundai       14.0  2.428571  3.646464e-01  2.0  2.100  2.4  2.650  3.3  14.0
# jeep           8.0  4.575000  1.015241e+00  3.0  3.925  4.7  4.950  6.1   8.0
# land rover     4.0  4.300000  2.581989e-01  4.0  4.150  4.3  4.450  4.6   4.0
# lincoln        3.0  5.400000  1.087792e-15  5.4  5.400  5.4  5.400  5.4   3.0
# mercury        4.0  4.400000  4.898979e-01  4.0  4.000  4.3  4.700  5.0   4.0
# ...

# %% [markdown]
# #### 11. How many different models are there?

# %%
mpg.groupby('model').describe()
# Out:
#                        displ                                                   \
#                        count      mean           std  min    25%   50%    75%
# model
# 4runner 4wd              6.0  3.483333  7.730890e-01  2.7  2.875  3.40  3.850
# a4                       7.0  2.328571  5.498918e-01  1.8  1.900  2.00  2.800
# a4 quattro               8.0  2.425000  5.775564e-01  1.8  1.950  2.40  2.875
# a6 quattro               3.0  3.366667  7.371115e-01  2.8  2.950  3.10  3.650
# altima                   6.0  2.800000  5.440588e-01  2.4  2.425  2.50  3.250
# c1500 suburban 2wd       5.0  5.520000  3.193744e-01  5.3  5.300  5.30  5.700
# camry                    7.0  2.671429  4.990467e-01  2.2  2.300  2.40  3.000
# camry solara             7.0  2.642857  4.466809e-01  2.2  2.300  2.40  3.000
# caravan 2wd             11.0  3.390909  4.526689e-01  2.4  3.300  3.30  3.800
# civic                    9.0  1.711111  1.452966e-01  1.6  1.600  1.60  1.800
# ...

# %%
mpg.groupby('manufacturer').model.nunique().sum()
# Out:
# 38

# %% [markdown]
# #### 12. Create a column named mileage_difference like you did in the DataFrames exercises; this column should contain the difference between highway and city mileage for each car.

# %%
mpg['mileage_difference'] = mpg.highway - mpg.city

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
#        class  mileage_difference
# ...

# %% [markdown]
# #### 13. Create a column named average_mileage like you did in the DataFrames exercises; this is the mean of the city and highway mileage.

# %%
mpg['average_mileage'] = (mpg.city + mpg.highway) / 2

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
# ...

# %%
mpg[['city', 'highway']].agg('mean', axis=1)
# Out:
# 1      23.5
# 2      25.0
# 3      25.5
# 4      25.5
# 5      21.0
#        ...
# 230    23.5
# 231    25.0
# 232    21.0
# 233    22.0
# 234    21.5
# Length: 234, dtype: float64

# %% [markdown]
# #### 14. Create a new column on the mpg dataset named is_automatic that holds boolean values denoting whether the car has an automatic transmission.

# %%
mpg.trans.unique()
# Out:
# array(['auto(l5)', 'manual(m5)', 'manual(m6)', 'auto(av)', 'auto(s6)',
#        'auto(l4)', 'auto(l3)', 'auto(l6)', 'auto(s5)', 'auto(s4)'],
#       dtype=object)

# %%
mpg['is_automatic'] = mpg.trans.str.contains('auto')

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  city  highway fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f    21       30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f    16       26  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...      ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f    19       28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f    21       29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f    16       26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f    18       26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f    17       26  p
#
# ...

# %% [markdown]
# #### 15. Using the mpg dataset, find out which which manufacturer has the best miles per gallon on average?

# %%
man_avg_mpg = mpg.groupby('manufacturer').average_mileage.agg(['mean'])

# %%
man_avg_mpg[man_avg_mpg == man_avg_mpg.max()].sort_values(by='mean').head(1)
# Out:
#               mean
# manufacturer
# honda         28.5

# %%
mpg.groupby('manufacturer').average_mileage.mean().nlargest(1)
# Out:
# manufacturer
# honda    28.5
# Name: average_mileage, dtype: float64

# %% [markdown]
# #### 16. Do automatic or manual cars have better miles per gallon?

# %%
mpg[mpg.trans.str.contains('auto')].describe()
# Out:
#             displ         year         cyl        city     highway  \
# count  157.000000   157.000000  157.000000  157.000000  157.000000
# mean     3.719745  2003.757962    6.203822   15.968153   22.292994
# std      1.272210     4.506976    1.584131    3.848777    5.623054
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.500000  1999.000000    4.000000   13.000000   17.000000
# 50%      3.800000  2008.000000    6.000000   16.000000   22.000000
# 75%      4.700000  2008.000000    8.000000   18.000000   26.000000
# max      6.500000  2008.000000    8.000000   29.000000   41.000000
#
#        mileage_difference  average_mileage
# count          157.000000       157.000000
# mean             6.324841        19.130573
# std              2.256661         4.684312
# min              3.000000        10.500000
# 25%              4.000000        15.000000
# 50%              6.000000        19.000000
# 75%              8.000000        22.500000
# ...

# %%
mpg[mpg.trans.str.contains('manual')].describe()
# Out:
#            displ         year        cyl       city    highway  \
# count  77.000000    77.000000  77.000000  77.000000  77.000000
# mean    2.966234  2002.974026   5.246753  18.675325  25.779221
# std     1.187059     4.498462   1.479294   4.488118   5.961772
# min     1.600000  1999.000000   4.000000   9.000000  12.000000
# 25%     2.000000  1999.000000   4.000000  15.000000  23.000000
# 50%     2.500000  1999.000000   4.000000  18.000000  26.000000
# 75%     3.500000  2008.000000   6.000000  21.000000  29.000000
# max     7.000000  2008.000000   8.000000  35.000000  44.000000
#
#        mileage_difference  average_mileage
# count           77.000000        77.000000
# mean             7.103896        22.227273
# std              2.197992         5.160927
# min              2.000000        10.500000
# 25%              6.000000        19.500000
# 50%              8.000000        22.000000
# 75%              8.000000        25.000000
# max             11.000000        39.500000

# %%
mpg.groupby('is_automatic').mean().average_mileage
# Out:
# is_automatic
# False    22.227273
# True     19.130573
# Name: average_mileage, dtype: float64

# %% [markdown]
# # Exercises III

# %% [markdown]
# #### 1. Use your get_db_url function to help you explore the data from the chipotle database.

# %%
url = get_db_url('chipotle')

# %%
orders = pd.read_sql('select * from orders', url)

# %% [markdown]
# #### 2. What is the total price for each order?

# %%
orders
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# ...

# %%
orders['item_price'] = orders.item_price.str.replace('$','', regex=True).astype(float)

# %%
orders.groupby(['order_id']).item_price.sum()
# Out:
# order_id
# 1       11.56
# 2       16.98
# 3       12.67
# 4       21.00
# 5       13.70
#         ...
# 1830    23.00
# 1831    12.90
# 1832    13.20
# 1833    23.50
# 1834    28.75
# Name: item_price, Length: 1834, dtype: float64

# %% [markdown]
# #### 3. What are the most popular 3 items?

# %%
orders.groupby(['item_name']).sum().sort_values(by='quantity', ascending=False).head(3)
# Out:
#                           id  order_id  quantity  item_price
# item_name
# Chicken Bowl         1780635    713926       761     7342.73
# Chicken Burrito      1238770    497303       591     5575.82
# Chips and Guacamole  1122252    449959       506     2201.04

# %% [markdown]
# #### 4. Which item has produced the most revenue?

# %%
orders.groupby(['item_name']).sum().sort_values(by='item_price', ascending=False).head()
# Out:
#                           id  order_id  quantity  item_price
# item_name
# Chicken Bowl         1780635    713926       761     7342.73
# Chicken Burrito      1238770    497303       591     5575.82
# Steak Burrito         818163    328437       386     3851.43
# Steak Bowl            482932    193752       221     2260.19
# Chips and Guacamole  1122252    449959       506     2201.04

# %% [markdown]
# #### 5. Join the employees and titles DataFrames together.

# %%
url2 = get_db_url('employees')

# %%
employees = pd.read_sql('select * from employees', url2)
employees
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12
# ...        ...         ...        ...       ...    ...         ...
# 300019  499995  1958-09-24     Dekang  Lichtner      F  1993-01-12
# 300020  499996  1953-03-07       Zito      Baaz      M  1990-09-27
# 300021  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 300022  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 300023  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
# [300024 rows x 6 columns]

# %%
titles = pd.read_sql('select * from titles', url2)
titles
# Out:
#         emp_no            title   from_date     to_date
# 0        10001  Senior Engineer  1986-06-26  9999-01-01
# 1        10002            Staff  1996-08-03  9999-01-01
# 2        10003  Senior Engineer  1995-12-03  9999-01-01
# 3        10004         Engineer  1986-12-01  1995-12-01
# 4        10004  Senior Engineer  1995-12-01  9999-01-01
# ...        ...              ...         ...         ...
# 443303  499997         Engineer  1987-08-30  1992-08-29
# 443304  499997  Senior Engineer  1992-08-29  9999-01-01
# 443305  499998     Senior Staff  1998-12-27  9999-01-01
# 443306  499998            Staff  1993-12-27  1998-12-27
# 443307  499999         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 4 columns]

# %%
emp_titles = employees.merge(titles, on='emp_no', how='inner')

# %%
emp_titles
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date  \
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# ...        ...         ...        ...       ...    ...         ...
# 443303  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443304  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443305  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443306  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443307  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
#                   title   from_date     to_date
# 0       Senior Engineer  1986-06-26  9999-01-01
# 1                 Staff  1996-08-03  9999-01-01
# ...

# %% [markdown]
# #### 6. For each title, find the hire date of the employee that was hired most recently with that title.

# %%
emp_titles.groupby(['title'])['hire_date'].max()
# Out:
# title
# Assistant Engineer    1999-12-24
# Engineer              2000-01-28
# Manager               1992-02-05
# Senior Engineer       2000-01-01
# Senior Staff          2000-01-13
# Staff                 2000-01-12
# Technique Leader      1999-12-31
# Name: hire_date, dtype: object

# %% [markdown]
# #### 7. Write the code necessary to create a cross tabulation of the number of titles by department. (Hint: this will involve a combination of SQL code to pull the necessary data and python/pandas code to perform the manipulations.)

# %%
employee_dept = pd.read_sql('''select *
                                from titles
                                join dept_emp using(emp_no)
                                join departments using(dept_no)
                                where titles.to_date > now()
                                    and dept_emp.to_date > now()

                            ''', url2)
employee_dept
# Out:
#        dept_no  emp_no         title   from_date     to_date   from_date  \
# 0         d009   10038  Senior Staff  1996-09-20  9999-01-01  1989-09-20
# 1         d009   10049  Senior Staff  2000-05-04  9999-01-01  1992-05-04
# 2         d009   10060  Senior Staff  1996-05-28  9999-01-01  1992-11-11
# 3         d009   10088  Senior Staff  1993-09-02  9999-01-01  1992-03-21
# 4         d009   10112         Staff  1998-05-01  9999-01-01  1998-05-01
# ...        ...     ...           ...         ...         ...         ...
# 240119    d007  499966  Senior Staff  1990-06-13  9999-01-01  1985-06-13
# 240120    d007  499976  Senior Staff  1988-12-26  9999-01-01  1988-12-26
# 240121    d007  499980  Senior Staff  1999-02-11  9999-01-01  1991-02-11
# 240122    d007  499986  Senior Staff  1992-08-11  9999-01-01  1985-08-11
# 240123    d007  499987         Staff  1999-12-21  9999-01-01  1999-12-21
#
#            to_date         dept_name
# 0       9999-01-01  Customer Service
# ...

# %%
pd.crosstab(employee_dept['title'], employee_dept['dept_name']).T
# Out:
# title               Assistant Engineer  Engineer  Manager  Senior Engineer  \
# dept_name
# Customer Service                    68       627        1             1790
# Development                       1652     14040        1            38816
# Finance                              0         0        1                0
# Human Resources                      0         0        1                0
# Marketing                            0         0        1                0
# Production                        1402     12081        1            33625
# Quality Management                 389      3405        1             9458
# Research                            77       830        1             2250
# Sales                                0         0        1                0
#
# title               Senior Staff  Staff  Technique Leader
# dept_name
# Customer Service           11268   3574               241
# Development                 1085    315              5477
# ...
